# %%
import tensorflow as tf
from tensorflow import keras
print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.4.0
# 2.4.0

# %%
#loading mnist fashion dataset
from keras.datasets import fashion_mnist
(X_train, Y_train), (X_test, Y_test) = fashion_mnist.load_data()
print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28) (60000,) (10000, 28, 28) (10000,)

# %%
#display few images from dataset
import matplotlib.pyplot as plt
# %matplotlib inline
for i in range(9):
    plt.subplot(330+1+i)
    plt.imshow(X_train[i])
plt.show()

# %%
#reshape the data to flatten
reshaped=784
X_train = X_train.reshape(60000,reshaped)
X_test = X_test.reshape(10000,reshaped)

#convert the data type to float
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

#normalizing the input
X_train /= 255
X_test /= 255

#one-hot encoding the labels, there are 10 labels in the dataset
Y_train = tf.keras.utils.to_categorical(Y_train, 10)
Y_test = tf.keras.utils.to_categorical(Y_test, 10)
print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)
# Out:
# (60000, 784) (60000, 10) (10000, 784) (10000, 10)

# %% [markdown]
# # model_0: Single Layer Perceptron Model

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras import Sequential
model_0 = Sequential()
model_0.add(Dense(10, input_shape=(784,), name="single_layer", activation='softmax'))

# %%
#compiling the model
model_0.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#training the model
training = model_0.fit(X_train, Y_train, batch_size=64, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 750/750 [==============================] - 2s 2ms/step - loss: 1.3293 - accuracy: 0.6010 - val_loss: 0.7571 - val_accuracy: 0.7613
# Epoch 2/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.7264 - accuracy: 0.7695 - val_loss: 0.6557 - val_accuracy: 0.7891
# Epoch 3/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.6457 - accuracy: 0.7945 - val_loss: 0.6066 - val_accuracy: 0.8016
# Epoch 4/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.5997 - accuracy: 0.8079 - val_loss: 0.5784 - val_accuracy: 0.8100
# Epoch 5/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.5770 - accuracy: 0.8109 - val_loss: 0.5585 - val_accuracy: 0.8142
# Epoch 6/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.5527 - accuracy: 0.8182 - val_loss: 0.5426 - val_accuracy: 0.8191
# Epoch 7/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.5399 - accuracy: 0.8214 - val_loss: 0.5310 - val_accuracy: 0.8217
# Epoch 8/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.5265 - accuracy: 0.8265 - val_loss: 0.5223 - val_accuracy: 0.8228
# Epoch 9/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.5167 - accuracy: 0.8287 - val_loss: 0.5151 - val_accuracy: 0.8244
# Epoch 10/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.5079 - accuracy: 0.8295 - val_loss: 0.5105 - val_accuracy: 0.8253
# Epoch 11/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.5053 - accuracy: 0.8320 - val_loss: 0.5002 - val_accuracy: 0.8307
# Epoch 12/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4940 - accuracy: 0.8351 - val_loss: 0.4960 - val_accuracy: 0.8304
# Epoch 13/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4857 - accuracy: 0.8371 - val_loss: 0.4908 - val_accuracy: 0.8320
# Epoch 14/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4862 - accuracy: 0.8367 - val_loss: 0.4876 - val_accuracy: 0.8336
# Epoch 15/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4748 - accuracy: 0.8420 - val_loss: 0.4837 - val_accuracy: 0.8342
# Epoch 16/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4740 - accuracy: 0.8401 - val_loss: 0.4810 - val_accuracy: 0.8357
# Epoch 17/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4693 - accuracy: 0.8433 - val_loss: 0.4765 - val_accuracy: 0.8374
# Epoch 18/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4638 - accuracy: 0.8433 - val_loss: 0.4738 - val_accuracy: 0.8381
# Epoch 19/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4627 - accuracy: 0.8453 - val_loss: 0.4714 - val_accuracy: 0.8396
# Epoch 20/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4613 - accuracy: 0.8426 - val_loss: 0.4691 - val_accuracy: 0.8384
# Epoch 21/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4629 - accuracy: 0.8438 - val_loss: 0.4675 - val_accuracy: 0.8405
# Epoch 22/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4562 - accuracy: 0.8432 - val_loss: 0.4649 - val_accuracy: 0.8408
# Epoch 23/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4499 - accuracy: 0.8496 - val_loss: 0.4642 - val_accuracy: 0.8407
# Epoch 24/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4523 - accuracy: 0.8475 - val_loss: 0.4618 - val_accuracy: 0.8412
# Epoch 25/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4488 - accuracy: 0.8484 - val_loss: 0.4608 - val_accuracy: 0.8430
# Epoch 26/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4510 - accuracy: 0.8473 - val_loss: 0.4577 - val_accuracy: 0.8425
# Epoch 27/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4484 - accuracy: 0.8482 - val_loss: 0.4558 - val_accuracy: 0.8436
# Epoch 28/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4468 - accuracy: 0.8491 - val_loss: 0.4570 - val_accuracy: 0.8447
# Epoch 29/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4394 - accuracy: 0.8502 - val_loss: 0.4538 - val_accuracy: 0.8443
# Epoch 30/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4328 - accuracy: 0.8511 - val_loss: 0.4529 - val_accuracy: 0.8441
# Epoch 31/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4429 - accuracy: 0.8496 - val_loss: 0.4521 - val_accuracy: 0.8444
# Epoch 32/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4398 - accuracy: 0.8535 - val_loss: 0.4502 - val_accuracy: 0.8443
# Epoch 33/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4367 - accuracy: 0.8523 - val_loss: 0.4486 - val_accuracy: 0.8471
# Epoch 34/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4372 - accuracy: 0.8524 - val_loss: 0.4483 - val_accuracy: 0.8458
# Epoch 35/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4392 - accuracy: 0.8502 - val_loss: 0.4475 - val_accuracy: 0.8457
# Epoch 36/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4323 - accuracy: 0.8532 - val_loss: 0.4480 - val_accuracy: 0.8457
# Epoch 37/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4315 - accuracy: 0.8513 - val_loss: 0.4453 - val_accuracy: 0.8468
# Epoch 38/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4319 - accuracy: 0.8530 - val_loss: 0.4461 - val_accuracy: 0.8462
# Epoch 39/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4302 - accuracy: 0.8533 - val_loss: 0.4433 - val_accuracy: 0.8478
# Epoch 40/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4341 - accuracy: 0.8518 - val_loss: 0.4429 - val_accuracy: 0.8474
# Epoch 41/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4354 - accuracy: 0.8514 - val_loss: 0.4424 - val_accuracy: 0.8480
# Epoch 42/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4298 - accuracy: 0.8543 - val_loss: 0.4421 - val_accuracy: 0.8472
# Epoch 43/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4314 - accuracy: 0.8533 - val_loss: 0.4413 - val_accuracy: 0.8493
# Epoch 44/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.4249 - accuracy: 0.8533 - val_loss: 0.4401 - val_accuracy: 0.8484
# Epoch 45/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4254 - accuracy: 0.8557 - val_loss: 0.4398 - val_accuracy: 0.8493
# Epoch 46/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4209 - accuracy: 0.8573 - val_loss: 0.4398 - val_accuracy: 0.8488
# Epoch 47/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4244 - accuracy: 0.8553 - val_loss: 0.4380 - val_accuracy: 0.8500
# Epoch 48/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4158 - accuracy: 0.8590 - val_loss: 0.4381 - val_accuracy: 0.8478
# Epoch 49/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4181 - accuracy: 0.8569 - val_loss: 0.4364 - val_accuracy: 0.8511
# Epoch 50/50
# 750/750 [==============================] - 1s 1ms/step - loss: 0.4173 - accuracy: 0.8579 - val_loss: 0.4363 - val_accuracy: 0.8504

# %%
#visualizing the change in accuracy vs epochs
plt.plot(training.history['accuracy'])
plt.plot(training.history['val_accuracy'])
plt.title('model_accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#evaluating the model on test data
test_loss, test_accuracy = model_0.evaluate(X_test, Y_test)
print('Test Accuracy:', test_accuracy)
# Out:
# 313/313 [==============================] - 0s 887us/step - loss: 0.4628 - accuracy: 0.8393
# Test Accuracy: 0.8392999768257141

# %%
#model summary
model_0.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# single_layer (Dense)         (None, 10)                7850
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # model_1: Multilayer Perceptron Model with Hidden Layer

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras import Sequential

#Most common type of model is a stack of layers
model_1 = tf.keras.Sequential()
N_hidden = 64
# Adds a densely-connected layer with 64 units to the model:
model_1.add(Dense(N_hidden, name='frist_layer', input_shape=(784,), activation = 'relu'))
# Now the model will take as input arrays of shape (*, 784)# and output arrays of shape (*, 64)

# Adding another dense layer:
model_1.add(Dense(N_hidden, name='second_layer', activation='relu'))
# After the first layer, you don't need to specify the size of the input anymore:
# Add an output layer with 10 output units (10 different classes):
model_1.add(Dense(10, name='softmax_layer', activation = 'softmax'))

# %%
# Compiling the model.
model_1.compile(optimizer='SGD', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
training = model_1.fit(X_train, Y_train, batch_size=64, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 750/750 [==============================] - 2s 2ms/step - loss: 1.4625 - accuracy: 0.5292 - val_loss: 0.6691 - val_accuracy: 0.7749
# Epoch 2/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.6374 - accuracy: 0.7828 - val_loss: 0.5575 - val_accuracy: 0.8076
# Epoch 3/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.5442 - accuracy: 0.8137 - val_loss: 0.5101 - val_accuracy: 0.8229
# Epoch 4/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.5101 - accuracy: 0.8246 - val_loss: 0.4861 - val_accuracy: 0.8300
# Epoch 5/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.4735 - accuracy: 0.8360 - val_loss: 0.4649 - val_accuracy: 0.8356
# Epoch 6/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4577 - accuracy: 0.8373 - val_loss: 0.4596 - val_accuracy: 0.8420
# Epoch 7/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.4372 - accuracy: 0.8492 - val_loss: 0.4420 - val_accuracy: 0.8450
# Epoch 8/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4330 - accuracy: 0.8510 - val_loss: 0.4390 - val_accuracy: 0.8447
# Epoch 9/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4160 - accuracy: 0.8561 - val_loss: 0.4246 - val_accuracy: 0.8499
# Epoch 10/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4119 - accuracy: 0.8550 - val_loss: 0.4413 - val_accuracy: 0.8448
# Epoch 11/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.4029 - accuracy: 0.8571 - val_loss: 0.4160 - val_accuracy: 0.8517
# Epoch 12/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3951 - accuracy: 0.8616 - val_loss: 0.4103 - val_accuracy: 0.8527
# Epoch 13/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3912 - accuracy: 0.8634 - val_loss: 0.4135 - val_accuracy: 0.8540
# Epoch 14/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3844 - accuracy: 0.8632 - val_loss: 0.4018 - val_accuracy: 0.8570
# Epoch 15/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3746 - accuracy: 0.8675 - val_loss: 0.4178 - val_accuracy: 0.8536
# Epoch 16/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3721 - accuracy: 0.8662 - val_loss: 0.3918 - val_accuracy: 0.8626
# Epoch 17/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3715 - accuracy: 0.8669 - val_loss: 0.3952 - val_accuracy: 0.8574
# Epoch 18/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3606 - accuracy: 0.8738 - val_loss: 0.3857 - val_accuracy: 0.8654
# Epoch 19/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3563 - accuracy: 0.8709 - val_loss: 0.3825 - val_accuracy: 0.8648
# Epoch 20/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3563 - accuracy: 0.8742 - val_loss: 0.3838 - val_accuracy: 0.8670
# Epoch 21/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3503 - accuracy: 0.8764 - val_loss: 0.3859 - val_accuracy: 0.8672
# Epoch 22/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3505 - accuracy: 0.8771 - val_loss: 0.3738 - val_accuracy: 0.8673
# Epoch 23/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3436 - accuracy: 0.8795 - val_loss: 0.3719 - val_accuracy: 0.8675
# Epoch 24/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3393 - accuracy: 0.8789 - val_loss: 0.3658 - val_accuracy: 0.8725
# Epoch 25/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3347 - accuracy: 0.8807 - val_loss: 0.3675 - val_accuracy: 0.8703
# Epoch 26/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3314 - accuracy: 0.8833 - val_loss: 0.3631 - val_accuracy: 0.8718
# Epoch 27/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3298 - accuracy: 0.8840 - val_loss: 0.3864 - val_accuracy: 0.8652
# Epoch 28/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3283 - accuracy: 0.8817 - val_loss: 0.3605 - val_accuracy: 0.8738
# Epoch 29/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3252 - accuracy: 0.8846 - val_loss: 0.3612 - val_accuracy: 0.8717
# Epoch 30/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3186 - accuracy: 0.8853 - val_loss: 0.3631 - val_accuracy: 0.8706
# Epoch 31/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3197 - accuracy: 0.8851 - val_loss: 0.3572 - val_accuracy: 0.8750
# Epoch 32/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3156 - accuracy: 0.8859 - val_loss: 0.3531 - val_accuracy: 0.8752
# Epoch 33/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3111 - accuracy: 0.8885 - val_loss: 0.3528 - val_accuracy: 0.8763
# Epoch 34/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3128 - accuracy: 0.8877 - val_loss: 0.3608 - val_accuracy: 0.8715
# Epoch 35/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3064 - accuracy: 0.8913 - val_loss: 0.3497 - val_accuracy: 0.8773
# Epoch 36/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3024 - accuracy: 0.8911 - val_loss: 0.3495 - val_accuracy: 0.8780
# Epoch 37/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3021 - accuracy: 0.8913 - val_loss: 0.3518 - val_accuracy: 0.8748
# Epoch 38/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3028 - accuracy: 0.8908 - val_loss: 0.3510 - val_accuracy: 0.8773
# Epoch 39/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3005 - accuracy: 0.8933 - val_loss: 0.3495 - val_accuracy: 0.8766
# Epoch 40/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.2994 - accuracy: 0.8914 - val_loss: 0.3554 - val_accuracy: 0.8763
# Epoch 41/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2968 - accuracy: 0.8948 - val_loss: 0.3630 - val_accuracy: 0.8698
# Epoch 42/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2937 - accuracy: 0.8935 - val_loss: 0.3429 - val_accuracy: 0.8808
# Epoch 43/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2843 - accuracy: 0.8969 - val_loss: 0.3456 - val_accuracy: 0.8798
# Epoch 44/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2855 - accuracy: 0.8974 - val_loss: 0.3503 - val_accuracy: 0.8753
# Epoch 45/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2903 - accuracy: 0.8960 - val_loss: 0.3484 - val_accuracy: 0.8759
# Epoch 46/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2842 - accuracy: 0.8991 - val_loss: 0.3504 - val_accuracy: 0.8783
# Epoch 47/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.2815 - accuracy: 0.8999 - val_loss: 0.3445 - val_accuracy: 0.8808
# Epoch 48/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2784 - accuracy: 0.9001 - val_loss: 0.3405 - val_accuracy: 0.8817
# Epoch 49/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2765 - accuracy: 0.9002 - val_loss: 0.3392 - val_accuracy: 0.8817
# Epoch 50/50
# 750/750 [==============================] - 1s 2ms/step - loss: 0.2763 - accuracy: 0.9013 - val_loss: 0.3438 - val_accuracy: 0.8801

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# list all data in training
print(training.history.keys())
# summarize training for accuracy
plt.plot(training.history['accuracy'])
plt.plot(training.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#evaluating the model
test_loss, test_acc = model_1.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3635 - accuracy: 0.8707
# Test accuracy: 0.8707000017166138

# %%
model_1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# frist_layer (Dense)          (None, 64)                50240
# _________________________________________________________________
# second_layer (Dense)         (None, 64)                4160
# _________________________________________________________________
# softmax_layer (Dense)        (None, 10)                650
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # model_2: Adding drop out layer to prevent overfitting

# %%
from tensorflow.keras.layers import Dropout

#Most common type of model is a stack of layers
model_2 = tf.keras.Sequential()
N_hidden = 64
# Adds a densely-connected layer with 64 units to the model:
model_2.add(Dense(N_hidden, name='dense_layer', input_shape=(784,), activation = 'relu'))
# Now the model will take as input arrays of shape (*, 784)# and output arrays of shape (*, 64)
model_2.add(Dropout(0.3))
# Adding another dense layer:
model_2.add(Dense(N_hidden, name='dense_layer_2', activation='relu'))
model_2.add(Dropout(0.3))

# Add an output layer with 10 output units (10 different classes):
model_2.add(Dense(10, name='dense_layer_3', activation = 'softmax'))

# %%
# Compiling the model.
model_2.compile(optimizer='SGD', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Training the model. 
training = model_2.fit(X_train, Y_train, batch_size=64, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 750/750 [==============================] - 2s 2ms/step - loss: 1.7086 - accuracy: 0.4083 - val_loss: 0.8008 - val_accuracy: 0.7241
# Epoch 2/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.9474 - accuracy: 0.6607 - val_loss: 0.6576 - val_accuracy: 0.7711
# Epoch 3/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.7961 - accuracy: 0.7236 - val_loss: 0.5879 - val_accuracy: 0.7956
# Epoch 4/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.7153 - accuracy: 0.7516 - val_loss: 0.5444 - val_accuracy: 0.8098
# Epoch 5/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.6744 - accuracy: 0.7677 - val_loss: 0.5156 - val_accuracy: 0.8171
# Epoch 6/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.6296 - accuracy: 0.7806 - val_loss: 0.4945 - val_accuracy: 0.8252
# Epoch 7/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5999 - accuracy: 0.7940 - val_loss: 0.4796 - val_accuracy: 0.8302
# Epoch 8/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5828 - accuracy: 0.7972 - val_loss: 0.4653 - val_accuracy: 0.8338
# Epoch 9/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5640 - accuracy: 0.8024 - val_loss: 0.4551 - val_accuracy: 0.8351
# Epoch 10/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.8094 - val_loss: 0.4471 - val_accuracy: 0.8366
# Epoch 11/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5340 - accuracy: 0.8152 - val_loss: 0.4366 - val_accuracy: 0.8421
# Epoch 12/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5241 - accuracy: 0.8187 - val_loss: 0.4336 - val_accuracy: 0.8417
# Epoch 13/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5156 - accuracy: 0.8195 - val_loss: 0.4252 - val_accuracy: 0.8462
# Epoch 14/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5064 - accuracy: 0.8234 - val_loss: 0.4212 - val_accuracy: 0.8482
# Epoch 15/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5007 - accuracy: 0.8264 - val_loss: 0.4179 - val_accuracy: 0.8465
# Epoch 16/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4875 - accuracy: 0.8314 - val_loss: 0.4125 - val_accuracy: 0.8511
# Epoch 17/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4922 - accuracy: 0.8284 - val_loss: 0.4054 - val_accuracy: 0.8517
# Epoch 18/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4796 - accuracy: 0.8349 - val_loss: 0.4066 - val_accuracy: 0.8524
# Epoch 19/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4787 - accuracy: 0.8334 - val_loss: 0.4032 - val_accuracy: 0.8527
# Epoch 20/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4795 - accuracy: 0.8319 - val_loss: 0.3993 - val_accuracy: 0.8558
# Epoch 21/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4565 - accuracy: 0.8391 - val_loss: 0.3963 - val_accuracy: 0.8568
# Epoch 22/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4687 - accuracy: 0.8391 - val_loss: 0.3951 - val_accuracy: 0.8573
# Epoch 23/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4523 - accuracy: 0.8421 - val_loss: 0.3891 - val_accuracy: 0.8571
# Epoch 24/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4504 - accuracy: 0.8425 - val_loss: 0.3889 - val_accuracy: 0.8600
# Epoch 25/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4430 - accuracy: 0.8436 - val_loss: 0.3836 - val_accuracy: 0.8608
# Epoch 26/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4496 - accuracy: 0.8423 - val_loss: 0.3846 - val_accuracy: 0.8622
# Epoch 27/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4398 - accuracy: 0.8468 - val_loss: 0.3824 - val_accuracy: 0.8608
# Epoch 28/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4457 - accuracy: 0.8451 - val_loss: 0.3813 - val_accuracy: 0.8633
# Epoch 29/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4412 - accuracy: 0.8470 - val_loss: 0.3754 - val_accuracy: 0.8640
# Epoch 30/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4299 - accuracy: 0.8513 - val_loss: 0.3739 - val_accuracy: 0.8637
# Epoch 31/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4260 - accuracy: 0.8503 - val_loss: 0.3741 - val_accuracy: 0.8658
# Epoch 32/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4257 - accuracy: 0.8517 - val_loss: 0.3724 - val_accuracy: 0.8658
# Epoch 33/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4241 - accuracy: 0.8507 - val_loss: 0.3727 - val_accuracy: 0.8660
# Epoch 34/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4187 - accuracy: 0.8540 - val_loss: 0.3698 - val_accuracy: 0.8665
# Epoch 35/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4163 - accuracy: 0.8539 - val_loss: 0.3666 - val_accuracy: 0.8653
# Epoch 36/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4206 - accuracy: 0.8542 - val_loss: 0.3686 - val_accuracy: 0.8668
# Epoch 37/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4148 - accuracy: 0.8516 - val_loss: 0.3666 - val_accuracy: 0.8678
# Epoch 38/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4086 - accuracy: 0.8556 - val_loss: 0.3643 - val_accuracy: 0.8674
# Epoch 39/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4017 - accuracy: 0.8587 - val_loss: 0.3623 - val_accuracy: 0.8689
# Epoch 40/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4051 - accuracy: 0.8566 - val_loss: 0.3608 - val_accuracy: 0.8702
# Epoch 41/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4003 - accuracy: 0.8599 - val_loss: 0.3602 - val_accuracy: 0.8697
# Epoch 42/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4029 - accuracy: 0.8585 - val_loss: 0.3591 - val_accuracy: 0.8698
# Epoch 43/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3963 - accuracy: 0.8598 - val_loss: 0.3587 - val_accuracy: 0.8717
# Epoch 44/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3960 - accuracy: 0.8604 - val_loss: 0.3558 - val_accuracy: 0.8714
# Epoch 45/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3986 - accuracy: 0.8571 - val_loss: 0.3543 - val_accuracy: 0.8722
# Epoch 46/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3877 - accuracy: 0.8624 - val_loss: 0.3551 - val_accuracy: 0.8717
# Epoch 47/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3825 - accuracy: 0.8654 - val_loss: 0.3528 - val_accuracy: 0.8739
# Epoch 48/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3939 - accuracy: 0.8609 - val_loss: 0.3588 - val_accuracy: 0.8712
# Epoch 49/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3933 - accuracy: 0.8603 - val_loss: 0.3513 - val_accuracy: 0.8737
# Epoch 50/50
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3898 - accuracy: 0.8629 - val_loss: 0.3497 - val_accuracy: 0.8751

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# list all data in training
print(training.history.keys())
# summarize training for accuracy
plt.plot(training.history['accuracy'])
plt.plot(training.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#evaluate the model
test_loss, test_acc = model_2.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3753 - accuracy: 0.8657
# Test accuracy: 0.8657000064849854

# %%
model_2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_layer (Dense)          (None, 64)                50240
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_layer_2 (Dense)        (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 10)                650
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # model_3: Increase the hidden layer neurons

# %%
from tensorflow.keras.layers import Dropout

#Most common type of model is a stack of layers
model_3 = tf.keras.Sequential()
N_hidden = 128
# Adds a densely-connected layer with 128 units to the model:
model_3.add(Dense(N_hidden, name='dense_layer', input_shape=(784,), activation = 'relu'))
# Now the model will take as input arrays of shape (*, 784)# and output arrays of shape (*, 64)
model_3.add(Dropout(0.3))
# Adding another dense layer:
model_3.add(Dense(N_hidden, name='dense_layer_2', activation='relu'))
model_3.add(Dropout(0.3))

# Add an output layer with 10 output units (10 different classes):
model_3.add(Dense(10, name='dense_layer_3', activation = 'softmax'))

# %%
# Compiling the model.
model_3.compile(optimizer='SGD', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Training the model. 
training = model_3.fit(X_train, Y_train, batch_size=64, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 750/750 [==============================] - 2s 3ms/step - loss: 1.5864 - accuracy: 0.4618 - val_loss: 0.7185 - val_accuracy: 0.7639
# Epoch 2/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.8183 - accuracy: 0.7129 - val_loss: 0.5992 - val_accuracy: 0.7956
# Epoch 3/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.6993 - accuracy: 0.7565 - val_loss: 0.5393 - val_accuracy: 0.8127
# Epoch 4/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.6289 - accuracy: 0.7839 - val_loss: 0.5079 - val_accuracy: 0.8210
# Epoch 5/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5849 - accuracy: 0.7973 - val_loss: 0.4820 - val_accuracy: 0.8296
# Epoch 6/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5599 - accuracy: 0.8053 - val_loss: 0.4648 - val_accuracy: 0.8338
# Epoch 7/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5451 - accuracy: 0.8095 - val_loss: 0.4506 - val_accuracy: 0.8376
# Epoch 8/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5154 - accuracy: 0.8215 - val_loss: 0.4407 - val_accuracy: 0.8418
# Epoch 9/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.5074 - accuracy: 0.8203 - val_loss: 0.4299 - val_accuracy: 0.8452
# Epoch 10/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4917 - accuracy: 0.8282 - val_loss: 0.4207 - val_accuracy: 0.8464
# Epoch 11/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4772 - accuracy: 0.8287 - val_loss: 0.4155 - val_accuracy: 0.8470
# Epoch 12/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4652 - accuracy: 0.8370 - val_loss: 0.4065 - val_accuracy: 0.8538
# Epoch 13/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4573 - accuracy: 0.8391 - val_loss: 0.4030 - val_accuracy: 0.8533
# Epoch 14/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4558 - accuracy: 0.8397 - val_loss: 0.3977 - val_accuracy: 0.8547
# Epoch 15/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4434 - accuracy: 0.8448 - val_loss: 0.3921 - val_accuracy: 0.8581
# Epoch 16/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4363 - accuracy: 0.8444 - val_loss: 0.3872 - val_accuracy: 0.8593
# Epoch 17/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4347 - accuracy: 0.8484 - val_loss: 0.3865 - val_accuracy: 0.8606
# Epoch 18/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4254 - accuracy: 0.8533 - val_loss: 0.3827 - val_accuracy: 0.8620
# Epoch 19/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4173 - accuracy: 0.8524 - val_loss: 0.3770 - val_accuracy: 0.8641
# Epoch 20/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4162 - accuracy: 0.8540 - val_loss: 0.3766 - val_accuracy: 0.8639
# Epoch 21/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4177 - accuracy: 0.8511 - val_loss: 0.3746 - val_accuracy: 0.8653
# Epoch 22/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4099 - accuracy: 0.8550 - val_loss: 0.3690 - val_accuracy: 0.8663
# Epoch 23/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4049 - accuracy: 0.8574 - val_loss: 0.3674 - val_accuracy: 0.8657
# Epoch 24/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4027 - accuracy: 0.8575 - val_loss: 0.3628 - val_accuracy: 0.8686
# Epoch 25/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3967 - accuracy: 0.8601 - val_loss: 0.3607 - val_accuracy: 0.8687
# Epoch 26/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4005 - accuracy: 0.8577 - val_loss: 0.3606 - val_accuracy: 0.8702
# Epoch 27/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3757 - accuracy: 0.8691 - val_loss: 0.3574 - val_accuracy: 0.8703
# Epoch 28/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3882 - accuracy: 0.8647 - val_loss: 0.3554 - val_accuracy: 0.8706
# Epoch 29/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3809 - accuracy: 0.8656 - val_loss: 0.3515 - val_accuracy: 0.8713
# Epoch 30/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3853 - accuracy: 0.8625 - val_loss: 0.3520 - val_accuracy: 0.8727
# Epoch 31/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3680 - accuracy: 0.8692 - val_loss: 0.3498 - val_accuracy: 0.8733
# Epoch 32/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3704 - accuracy: 0.8696 - val_loss: 0.3476 - val_accuracy: 0.8754
# Epoch 33/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3683 - accuracy: 0.8687 - val_loss: 0.3479 - val_accuracy: 0.8747
# Epoch 34/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3638 - accuracy: 0.8692 - val_loss: 0.3443 - val_accuracy: 0.8760
# Epoch 35/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3621 - accuracy: 0.8705 - val_loss: 0.3454 - val_accuracy: 0.8765
# Epoch 36/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3637 - accuracy: 0.8709 - val_loss: 0.3440 - val_accuracy: 0.8763
# Epoch 37/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3640 - accuracy: 0.8698 - val_loss: 0.3423 - val_accuracy: 0.8760
# Epoch 38/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3615 - accuracy: 0.8697 - val_loss: 0.3408 - val_accuracy: 0.8770
# Epoch 39/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3603 - accuracy: 0.8712 - val_loss: 0.3427 - val_accuracy: 0.8749
# Epoch 40/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3552 - accuracy: 0.8729 - val_loss: 0.3369 - val_accuracy: 0.8787
# Epoch 41/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3526 - accuracy: 0.8768 - val_loss: 0.3384 - val_accuracy: 0.8794
# Epoch 42/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3504 - accuracy: 0.8759 - val_loss: 0.3351 - val_accuracy: 0.8787
# Epoch 43/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3458 - accuracy: 0.8778 - val_loss: 0.3336 - val_accuracy: 0.8778
# Epoch 44/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3416 - accuracy: 0.8769 - val_loss: 0.3340 - val_accuracy: 0.8808
# Epoch 45/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3494 - accuracy: 0.8728 - val_loss: 0.3368 - val_accuracy: 0.8779
# Epoch 46/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3434 - accuracy: 0.8779 - val_loss: 0.3329 - val_accuracy: 0.8811
# Epoch 47/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3339 - accuracy: 0.8801 - val_loss: 0.3305 - val_accuracy: 0.8786
# Epoch 48/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3434 - accuracy: 0.8788 - val_loss: 0.3280 - val_accuracy: 0.8817
# Epoch 49/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3381 - accuracy: 0.8788 - val_loss: 0.3274 - val_accuracy: 0.8802
# Epoch 50/50
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3375 - accuracy: 0.8791 - val_loss: 0.3270 - val_accuracy: 0.8832

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# list all data in training
print(training.history.keys())
# summarize training for accuracy
plt.plot(training.history['accuracy'])
plt.plot(training.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#evaluate the model
test_loss, test_acc = model_3.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3521 - accuracy: 0.8754
# Test accuracy: 0.8754000067710876

# %%
model_3.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_layer (Dense)          (None, 128)               100480
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_2 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # model_4: Increasing the hidden layers and changing the Optimizer

# %%
model_4 = tf.keras.Sequential()
N_hidden = 128
# Adds a densely-connected layer with 128 units to the model:
model_4.add(Dense(N_hidden, name='dense_layer', input_shape=(784,), activation = 'relu'))
# Now the model will take as input arrays of shape (*, 784)# and output arrays of shape (*, 64)
model_4.add(Dropout(0.3))

# Adding additional dense and dropout layers:
model_4.add(Dense(N_hidden, name='dense_layer_2', activation='relu'))
model_4.add(Dropout(0.3))

model_4.add(Dense(N_hidden, name='dense_layer_3', activation='relu'))
model_4.add(Dropout(0.3))

model_4.add(Dense(N_hidden, name='dense_layer_4', activation='relu'))
model_4.add(Dropout(0.3))

# Add an output layer with 10 output units (10 different classes):
model_4.add(Dense(10, name='dense_layer_5', activation = 'softmax'))

# %%
# Compiling the model with Adam optimizer
model_4.compile(optimizer='Adam', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Training the model. 
training = model_4.fit(X_train, Y_train, batch_size=128, epochs=30, validation_split=0.2)
# Out:
# Epoch 1/30
# 375/375 [==============================] - 3s 6ms/step - loss: 1.2523 - accuracy: 0.5332 - val_loss: 0.4827 - val_accuracy: 0.8286
# Epoch 2/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.5576 - accuracy: 0.8058 - val_loss: 0.4278 - val_accuracy: 0.8448
# Epoch 3/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4779 - accuracy: 0.8333 - val_loss: 0.3929 - val_accuracy: 0.8562
# Epoch 4/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4444 - accuracy: 0.8450 - val_loss: 0.3844 - val_accuracy: 0.8638
# Epoch 5/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4279 - accuracy: 0.8483 - val_loss: 0.3759 - val_accuracy: 0.8652
# Epoch 6/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4103 - accuracy: 0.8567 - val_loss: 0.3695 - val_accuracy: 0.8662
# Epoch 7/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3927 - accuracy: 0.8619 - val_loss: 0.3554 - val_accuracy: 0.8732
# Epoch 8/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3901 - accuracy: 0.8631 - val_loss: 0.3491 - val_accuracy: 0.8756
# Epoch 9/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3802 - accuracy: 0.8633 - val_loss: 0.3471 - val_accuracy: 0.8755
# Epoch 10/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3645 - accuracy: 0.8694 - val_loss: 0.3479 - val_accuracy: 0.8744
# Epoch 11/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3611 - accuracy: 0.8686 - val_loss: 0.3402 - val_accuracy: 0.8792
# Epoch 12/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3573 - accuracy: 0.8708 - val_loss: 0.3437 - val_accuracy: 0.8752
# Epoch 13/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3499 - accuracy: 0.8760 - val_loss: 0.3368 - val_accuracy: 0.8782
# Epoch 14/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3406 - accuracy: 0.8761 - val_loss: 0.3341 - val_accuracy: 0.8788
# Epoch 15/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3398 - accuracy: 0.8805 - val_loss: 0.3439 - val_accuracy: 0.8803
# Epoch 16/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3272 - accuracy: 0.8813 - val_loss: 0.3380 - val_accuracy: 0.8764
# Epoch 17/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.3349 - accuracy: 0.8783 - val_loss: 0.3273 - val_accuracy: 0.8820
# Epoch 18/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3227 - accuracy: 0.8824 - val_loss: 0.3347 - val_accuracy: 0.8798
# Epoch 19/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3234 - accuracy: 0.8816 - val_loss: 0.3476 - val_accuracy: 0.8775
# Epoch 20/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3275 - accuracy: 0.8811 - val_loss: 0.3386 - val_accuracy: 0.8758
# Epoch 21/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3188 - accuracy: 0.8856 - val_loss: 0.3310 - val_accuracy: 0.8780
# Epoch 22/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3186 - accuracy: 0.8847 - val_loss: 0.3307 - val_accuracy: 0.8825
# Epoch 23/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3081 - accuracy: 0.8888 - val_loss: 0.3285 - val_accuracy: 0.8826
# Epoch 24/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3066 - accuracy: 0.8905 - val_loss: 0.3306 - val_accuracy: 0.8827
# Epoch 25/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3157 - accuracy: 0.8860 - val_loss: 0.3236 - val_accuracy: 0.8867
# Epoch 26/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.3060 - accuracy: 0.8874 - val_loss: 0.3250 - val_accuracy: 0.8864
# Epoch 27/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.3019 - accuracy: 0.8917 - val_loss: 0.3338 - val_accuracy: 0.8808
# Epoch 28/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.3057 - accuracy: 0.8905 - val_loss: 0.3271 - val_accuracy: 0.8876
# Epoch 29/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.3004 - accuracy: 0.8908 - val_loss: 0.3205 - val_accuracy: 0.8883
# Epoch 30/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2987 - accuracy: 0.8899 - val_loss: 0.3341 - val_accuracy: 0.8817

# %%
#evaluate the model_4
test_loss, test_acc = model_4.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3512 - accuracy: 0.8768
# Test accuracy: 0.876800000667572

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# list all data in training
print(training.history.keys())
# summarize training for accuracy
plt.plot(training.history['accuracy'])
plt.plot(training.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model_4.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_layer (Dense)          (None, 128)               100480
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_2 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_4 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_5 (Dense)        (None, 10)                1290
# =================================================================
# Total params: 151,306
# Trainable params: 151,306
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # model_5: Manipulating the batch_size and epochs

# %%
model_5 = tf.keras.Sequential()
N_hidden = 128
# Adds a densely-connected layer with 128 units to the model:
model_5.add(Dense(N_hidden, name='dense_layer', input_shape=(784,), activation = 'relu'))
# Now the model will take as input arrays of shape (*, 784)# and output arrays of shape (*, 64)
model_5.add(Dropout(0.3))

# Adding additional dense and dropout layers:
model_5.add(Dense(N_hidden, name='dense_layer_2', activation='relu'))
model_5.add(Dropout(0.3))

model_5.add(Dense(N_hidden, name='dense_layer_3', activation='relu'))
model_5.add(Dropout(0.3))

model_5.add(Dense(N_hidden, name='dense_layer_4', activation='relu'))
model_5.add(Dropout(0.3))

# Add an output layer with 10 output units (10 different classes):
model_5.add(Dense(10, name='dense_layer_5', activation = 'softmax'))

# %%
# Compiling the model with Adam optimizer
model_5.compile(optimizer='Adam', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Training the model. 
training = model_5.fit(X_train, Y_train, batch_size=75, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 640/640 [==============================] - 3s 4ms/step - loss: 1.1269 - accuracy: 0.5727 - val_loss: 0.4647 - val_accuracy: 0.8324
# Epoch 2/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.5236 - accuracy: 0.8149 - val_loss: 0.4325 - val_accuracy: 0.8442
# Epoch 3/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.4722 - accuracy: 0.8337 - val_loss: 0.4096 - val_accuracy: 0.8538
# Epoch 4/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.4483 - accuracy: 0.8435 - val_loss: 0.3856 - val_accuracy: 0.8595
# Epoch 5/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.4240 - accuracy: 0.8515 - val_loss: 0.3770 - val_accuracy: 0.8663
# Epoch 6/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.4082 - accuracy: 0.8548 - val_loss: 0.3857 - val_accuracy: 0.8629
# Epoch 7/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.4034 - accuracy: 0.8536 - val_loss: 0.3715 - val_accuracy: 0.8708
# Epoch 8/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.3924 - accuracy: 0.8598 - val_loss: 0.3505 - val_accuracy: 0.8707
# Epoch 9/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.3793 - accuracy: 0.8627 - val_loss: 0.3522 - val_accuracy: 0.8763
# Epoch 10/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.3736 - accuracy: 0.8678 - val_loss: 0.3493 - val_accuracy: 0.8742
# Epoch 11/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.3723 - accuracy: 0.8694 - val_loss: 0.3414 - val_accuracy: 0.8706
# Epoch 12/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.3622 - accuracy: 0.8710 - val_loss: 0.3446 - val_accuracy: 0.8746
# Epoch 13/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.3569 - accuracy: 0.8721 - val_loss: 0.3460 - val_accuracy: 0.8766
# Epoch 14/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.3489 - accuracy: 0.8753 - val_loss: 0.3463 - val_accuracy: 0.8748
# Epoch 15/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.3462 - accuracy: 0.8773 - val_loss: 0.3323 - val_accuracy: 0.8826
# Epoch 16/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.3406 - accuracy: 0.8754 - val_loss: 0.3475 - val_accuracy: 0.8729
# Epoch 17/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.3436 - accuracy: 0.8770 - val_loss: 0.3307 - val_accuracy: 0.8816
# Epoch 18/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.3369 - accuracy: 0.8773 - val_loss: 0.3323 - val_accuracy: 0.8811
# Epoch 19/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.3348 - accuracy: 0.8816 - val_loss: 0.3359 - val_accuracy: 0.8813
# Epoch 20/20
# 640/640 [==============================] - 3s 4ms/step - loss: 0.3233 - accuracy: 0.8825 - val_loss: 0.3277 - val_accuracy: 0.8851

# %%
#evaluate the model_5
test_loss, test_acc = model_5.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3515 - accuracy: 0.8766
# Test accuracy: 0.8766000270843506

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# list all data in training
print(training.history.keys())
# summarize training for accuracy
plt.plot(training.history['accuracy'])
plt.plot(training.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model_5.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_layer (Dense)          (None, 128)               100480
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_2 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_layer_4 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_layer_5 (Dense)        (None, 10)                1290
# =================================================================
# Total params: 151,306
# Trainable params: 151,306
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # model_6: Final Model

# %%
model_6 = tf.keras.Sequential()
N_hidden = 512
# Adds a densely-connected layer with 128 units to the model:
model_6.add(Dense(N_hidden, name='dense_layer', input_shape=(784,), activation = 'relu'))
# Now the model will take as input arrays of shape (*, 784)# and output arrays of shape (*, 64)
model_6.add(Dropout(0.4))

# Adding additional dense and dropout layers:
model_6.add(Dense(N_hidden, name='dense_layer_2', activation='relu'))
model_6.add(Dropout(0.4))

model_6.add(Dense(N_hidden, name='dense_layer_3', activation='relu'))
model_6.add(Dropout(0.4))

model_6.add(Dense(N_hidden, name='dense_layer_4', activation='relu'))
model_6.add(Dropout(0.4))

# Add an output layer with 10 output units (10 different classes):
model_6.add(Dense(10, name='dense_layer_5', activation = 'softmax'))

# %%
# Compiling the model with Adam optimizer
model_6.compile(optimizer='Adam', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Training the model. 
training = model_6.fit(X_train, Y_train, batch_size=72, epochs=25, validation_split=0.2)
# Out:
# Epoch 1/25
# 667/667 [==============================] - 14s 20ms/step - loss: 0.9157 - accuracy: 0.6569 - val_loss: 0.4631 - val_accuracy: 0.8282
# Epoch 2/25
# 667/667 [==============================] - 14s 21ms/step - loss: 0.5025 - accuracy: 0.8212 - val_loss: 0.3973 - val_accuracy: 0.8550
# Epoch 3/25
# 667/667 [==============================] - 14s 21ms/step - loss: 0.4660 - accuracy: 0.8346 - val_loss: 0.3999 - val_accuracy: 0.8587
# Epoch 4/25
# 667/667 [==============================] - 14s 21ms/step - loss: 0.4364 - accuracy: 0.8432 - val_loss: 0.3962 - val_accuracy: 0.8623
# Epoch 5/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.4166 - accuracy: 0.8522 - val_loss: 0.3835 - val_accuracy: 0.8641
# Epoch 6/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.4147 - accuracy: 0.8536 - val_loss: 0.3751 - val_accuracy: 0.8612
# Epoch 7/25
# 667/667 [==============================] - 13s 19ms/step - loss: 0.4000 - accuracy: 0.8571 - val_loss: 0.3505 - val_accuracy: 0.8698
# Epoch 8/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3889 - accuracy: 0.8600 - val_loss: 0.3648 - val_accuracy: 0.8677
# Epoch 9/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3823 - accuracy: 0.8651 - val_loss: 0.3577 - val_accuracy: 0.8728
# Epoch 10/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3811 - accuracy: 0.8625 - val_loss: 0.3615 - val_accuracy: 0.8678
# Epoch 11/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3749 - accuracy: 0.8665 - val_loss: 0.3566 - val_accuracy: 0.8743
# Epoch 12/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3677 - accuracy: 0.8698 - val_loss: 0.3391 - val_accuracy: 0.8805
# Epoch 13/25
# 667/667 [==============================] - 13s 19ms/step - loss: 0.3630 - accuracy: 0.8704 - val_loss: 0.3434 - val_accuracy: 0.8766
# Epoch 14/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3569 - accuracy: 0.8695 - val_loss: 0.3472 - val_accuracy: 0.8798
# Epoch 15/25
# 667/667 [==============================] - 13s 19ms/step - loss: 0.3576 - accuracy: 0.8733 - val_loss: 0.3456 - val_accuracy: 0.8787
# Epoch 16/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3537 - accuracy: 0.8741 - val_loss: 0.3305 - val_accuracy: 0.8824
# Epoch 17/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3407 - accuracy: 0.8790 - val_loss: 0.3357 - val_accuracy: 0.8813
# Epoch 18/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3420 - accuracy: 0.8778 - val_loss: 0.3347 - val_accuracy: 0.8843
# Epoch 19/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3413 - accuracy: 0.8751 - val_loss: 0.3370 - val_accuracy: 0.8845
# Epoch 20/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3428 - accuracy: 0.8762 - val_loss: 0.3438 - val_accuracy: 0.8755
# Epoch 21/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3263 - accuracy: 0.8814 - val_loss: 0.3545 - val_accuracy: 0.8768
# Epoch 22/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3404 - accuracy: 0.8781 - val_loss: 0.3387 - val_accuracy: 0.8817
# Epoch 23/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3350 - accuracy: 0.8791 - val_loss: 0.3395 - val_accuracy: 0.8797
# Epoch 24/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3273 - accuracy: 0.8813 - val_loss: 0.3343 - val_accuracy: 0.8802
# Epoch 25/25
# 667/667 [==============================] - 13s 20ms/step - loss: 0.3377 - accuracy: 0.8781 - val_loss: 0.3567 - val_accuracy: 0.8771

# %%
#evaluate the model_6
test_loss, test_acc = model_6.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3797 - accuracy: 0.8705
# Test accuracy: 0.8705000281333923

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# list all data in training
print(training.history.keys())
# summarize training for accuracy
plt.plot(training.history['accuracy'])
plt.plot(training.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model_6.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_layer (Dense)          (None, 512)               401920
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_layer_2 (Dense)        (None, 512)               262656
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 512)               262656
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_layer_4 (Dense)        (None, 512)               262656
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_layer_5 (Dense)        (None, 10)                5130
# =================================================================
# Total params: 1,195,018
# Trainable params: 1,195,018
# Non-trainable params: 0
# _________________________________________________________________
